# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random
# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options = ["stone", "paper", "scissors"]
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
games_max=5
# Assign a variable to the number of games a player must win to win.
min_wins=2
# Preferably the value will be based on the number of maximum games
# Define a function that randomly returns one of the 3 options.
HUMAN_WIN=2
MACHINE_WIN=1
TIE=0
display = {HUMAN_WIN:"Human wins", MACHINE_WIN:"Machine wins", TIE:"Tie"}

def machine():
    return (random.choice(options))
def human(): # If it is not stone, paper or scissors keep asking until it is.
    entry = input()
    while entry not in options:
        print("Choose between 'stone', 'paper' or 'scissors': ", options)
        entry = input()
    return entry
def one_match():# Define a function that resolves a combat.
    value=TIE
    human_choix=human()        
    machine_choix=machine()
    print(machine_choix) 
    if human_choix=="scissors":
        if machine_choix=="paper":
            value=HUMAN_WIN
        elif machine_choix== "stone":
            value=MACHINE_WIN
        
    elif human_choix  == "paper":
        if machine_choix=="stone":
            value=HUMAN_WIN
        elif machine_choix =="scissors":
            value=MACHINE_WIN
        
    elif human_choix =="stone":
        if machine_choix  == "paper":
            value=MACHINE_WIN
        elif machine_choix=="scissors":
            value=HUMAN_WIN
    return value # Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Define a function that shows the choice of each player and the state of the game

# %%
def has_win(points):
    
    if points>=min_wins:
        return True
    return False
 

def should_stop(wins_h, wins_m, nombre_de_match):
    if has_win(wins_h):
        return True
    elif has_win(wins_m):
        return True
    elif nombre_de_match>=games_max:
        return True
    else:
        return False
    
   # return has_win(wins_h) or has_win(wins_m) or nombre_de_match >= games_max

# %%
# This function should be used every time accumulated points are updated
# Create two variables that accumulate the wins of each participant
def matches():
    mpoints=0
    hpoints=0
    number_matches=0
    
    
    while not should_stop(hpoints, mpoints, number_matches):  
        match=one_match()
        number_matches+=1
        #print(match)
        if match==MACHINE_WIN:
            print('machine wins')
            mpoints=mpoints+1
        elif match==HUMAN_WIN:
            print('human wins')
            hpoints=hpoints+1
        else:
            print('tie')
  
    return hpoints, mpoints, number_matches

def play():
    h, m, n= matches()
    
    if h>m:
        print("Human win", "Score", "h",h,"m",m, "no de match", n)
    elif h<m:
        print("Machine wins", "Score", "h",h,"m",m, "no de match", n)
    else:
        print("Tie")

# %%
play()
# Out:
# stone
# paper
# machine wins
# scissors
# paper
# human wins
# paper
# paper
# tie
# paper
# scissors
# machine wins
# Machine wins Score h 1 m 2 no de match 4

# %%
# Create a loop that iterates while no player reaches the minimum of wins


  # necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-26cfec8959aa> in <module>
#       8 #print("Results of X rounds:", points)
#       9     return
# ---> 10 x=min_wins_humain()
#      11 print(x)
#      12
#
# <ipython-input-4-26cfec8959aa> in min_wins_humain()
#       1 # Create a loop that iterates while no player reaches the minimum of wins
#       2 def min_wins_humain():
# ----> 3     while hpoints <= min_wins:
#       4         wins=accumulation_of_points()
#       5     print(wins)
#
# NameError: name 'hpoints' is not defined

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random
HUMAN_WIN=2
MACHINE_WIN=1
TIE=0
display = {HUMAN_WIN:"Human wins", MACHINE_WIN:"Machine wins", TIE:"Tie"}
#games_max=5
#min_wins=3
# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def entry(number):
    keypad_n=int(input("Please, input non even number : "))
    return(number)
def odd(check):
    #k=entry()
    num = k%2
    if num > 0:
        return True
    elif num == 0:
        return False
    return(check)
     
def number_matches(match_numbers):# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
    n = entry(number)
    result=odd(check)
   # if value== True:
        #print (n)
    while odd(check) ==False:
        print("Still need odd number, thank you :")
        n=entry(number)
    return (match_nubers)
def games_to_win(minimum_wins):
    matches_max=number_matches(match_number)
    min_wins=int(matches_max*.6)
    return(minimum_wins)

# %%
# Assign a list of 5 possible options.
options = ["paper", "scissors", "lizard", "spock", "stone"]
# This time the previously defined function is used
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def human(): # If it is not stone, paper or scissors keep asking until it is.
    humaninput = input("Please input your choice : 'stone', 'paper','scissors', 'spock' or 'lizard'")
    while humaninput not in options:
        print("Your input must be between following: ", options)
        humaninput = input()
    return humaninput
#hword=human()
#print("Human input is: ", hword)

def machine():
    return (random.choice(options))
#y=machine()
#print(y)
# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

# %%
def one_match():# Define a function that resolves a combat.
    value=TIE
    human_choix=human()        
    machine_choix=machine()
    #print(machine_choix) 
    if human_choix=="scissors":
        if machine_choix=="paper":
            value=HUMAN_WIN
        elif machine_choix== "stone":
            value=MACHINE_WIN
        elif machine_choix=="lizard":
            value=HUMAN_WIN
        elif machine_choix== "spock":
            value=MACHINE_WIN
        
    elif human_choix  == "paper":
        if machine_choix=="stone":
            value=HUMAN_WIN
        elif machine_choix =="lizard":
            value=MACHINE_WIN
        elif machine_choix=="spock":
            value=HUMAN_WIN
        elif machine_choix =="scissors":
            value=MACHINE_WIN
        
    elif human_choix =="stone":
        if machine_choix  == "paper":
            value=MACHINE_WIN
        elif machine_choix=="scissors":
            value=HUMAN_WIN
        elif machine_choix  == "spock":
            value=MACHINE_WIN
        elif machine_choix=="lizard":
            value=HUMAN_WIN
        
    elif human_choix =="lizard":
        if machine_choix  == "stone":
            value=MACHINE_WIN
        elif machine_choix=="paper":
            value=HUMAN_WIN
        elif machine_choix  == "scissors":
            value=MACHINE_WIN
        elif machine_choix=="spock":
            value=HUMAN_WIN
    
    elif human_choix =="spock":
        if machine_choix  == "lizard":
            value=MACHINE_WIN
        elif machine_choix=="stone":
            value=HUMAN_WIN
        elif machine_choix  == "paper":
            value=MACHINE_WIN
        elif machine_choix=="scissors":
            value=HUMAN_WIN                
            
    return value
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

# %%
def has_win(points):
    min_wins=games_to_win(minimum_wins)

    if points>=min_wins:
        return True
    return False

def should_stop(wins_h, wins_m, nombre_de_match):
    #games_max=number_matches()
    return has_win(wins_h) or has_win(wins_m) or nombre_de_match >= games_max

def matches():
    mpoints=0
    hpoints=0
    number_matches=0
        
    while not should_stop(hpoints, mpoints, number_matches):  
        match=one_match()
        number_matches+=1
        print(match)
        if match==MACHINE_WIN:
            print('machine wins')
            mpoints=mpoints+1
        elif match==HUMAN_WIN:
            print('human wins')
            hpoints=hpoints+1
        else:
            print('tie')
  
    return hpoints, mpoints, number_matches

def play():
    h, m, n= matches()
    
    if h>m:
        print("Human win", "Score", "Human:",h,"Machine:",m, "Qty match:", n)
    elif h<m:
        print("Machine wins", "Score", "Human:",h,"Machine:",m, "Qty match:", n)
    else:
        print("Tie")
play()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-82d802635c2a> in <module>
#      39     else:
#      40         print("Tie")
# ---> 41 play()
#
# <ipython-input-4-82d802635c2a> in play()
#      31
#      32 def play():
# ---> 33     h, m, n= matches()
#      34
#      35     if h>m:
#
# <ipython-input-4-82d802635c2a> in matches()
#      15     number_matches=0
#      16
# ---> 17     while not should_stop(hpoints, mpoints, number_matches):
#      18         match=one_match()
#      19         number_matches+=1
#
# <ipython-input-4-82d802635c2a> in should_stop(wins_h, wins_m, nombre_de_match)
#       8 def should_stop(wins_h, wins_m, nombre_de_match):
#       9     #games_max=number_matches()
# ---> 10     return has_win(wins_h) or has_win(wins_m) or nombre_de_match >= games_max
#      11
#      12 def matches():
#
# <ipython-input-4-82d802635c2a> in has_win(points)
#       1 def has_win(points):
# ----> 2     min_wins=games_to_win(minimum_wins)
#       3
#       4     if points>=min_wins:
#       5         return True
#
# NameError: name 'minimum_wins' is not defined
